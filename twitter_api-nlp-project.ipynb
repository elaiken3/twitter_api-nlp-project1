# %% [markdown]
# # Who said it on Twitter: Using the Twitter API and NLP to see which tweets are more likely to be yours

# %% [markdown]
# ## Goals
# ---
#
# Given two people We are going to attempt to classify which tweet came from whom.  There are a few steps to this:
# - Create a method to pull a list of tweets from the Twitter API
# - Perform proper preprocessing on our text
# - Engineer sentiment feature in our dataset using TextBlob
# - Explore supervised classification techniques

# %% [markdown]
# ## Some Boring Twitter Rules
# ---
#
# **Twitter notifies you they will rate limit your requests:**
#
# >THERE ARE LIMITS TO THE AMOUNT OF TIMES YOU CAN HIT THE API PER 15 MINUTE WINDOW. BEWARE!
#
# Here's a quick overview of what Twitter says are "[the rules](https://dev.twitter.com/rest/public/rate-limiting)":
#
# ![](https://snag.gy/yJ6vIH.jpg)

# %%
import numpy as np
import twitter, re, datetime, pandas as pd

twitter_keys = {
    'consumer_key':        'L4sziHBqV4VUIfKezbos0JMVl',
    'consumer_secret':     'lJau6R7GIHFwoGR5wB3PlLQPXBChwzJFJ9WGXXtazcDSA1Vb1X',
    'access_token_key':    '941359629606539264-05XcmQfdwMXTbPNWS3r7cZThvbQBxCK',
    'access_token_secret': 'VdE3VJVk6oxbohQGcw7WYA5Tg4Sr8kW9duTO1wxmB6qXk'
}

api = twitter.Api(
    consumer_key         =   twitter_keys['consumer_key'],
    consumer_secret      =   twitter_keys['consumer_secret'],
    access_token_key     =   twitter_keys['access_token_key'],
    access_token_secret  =   twitter_keys['access_token_secret'],
    tweet_mode = 'extended'
)

# %%
type(api)
# Out:
# twitter.api.Api

# %% [markdown]
# ### Below I use the GetUserTimeline method of twitter.api.Api object to get tweet text and tweet details for a user.

# %%
# Note: Count can't be greater than 200
x = api.GetUserTimeline(screen_name="HillaryClinton", count=20, include_rts=False)
x = [_.AsDict() for _ in x]

# %%
x[0]
# Out:
# {u'created_at': u'Fri Jan 19 19:08:40 +0000 2018',
#  u'favorite_count': 90621,
#  u'full_text': u'I\u2019m so heartened by all of you. Onward! https://t.co/vkRj7M3kBS',
#  u'hashtags': [],
#  u'id': 954430425321046016,
#  u'id_str': u'954430425321046016',
#  u'lang': u'en',
#  u'quoted_status': {u'created_at': u'Thu Jan 18 14:06:08 +0000 2018',
#   u'favorite_count': 10541,
#   u'full_text': u'New @TIME cover: A year ago, they marched. Now a record number of women are running for office https://t.co/Uc9ivXGS2q via @CharlotteAlter https://t.co/8jnQ9gWmur',
#   u'hashtags': [],
#   u'id': 953991903250386944,
#   u'id_str': u'953991903250386944',
#   u'lang': u'en',
#   u'media': [{u'display_url': u'pic.twitter.com/8jnQ9gWmur',
#     u'expanded_url': u'https://twitter.com/TIMEPolitics/status/953991903250386944/photo/1',
#     u'id': 953991895411318784,
#     u'media_url': u'http://pbs.twimg.com/media/DT1CkwyX4AAkH5W.jpg',
#     u'media_url_https': u'https://pbs.twimg.com/media/DT1CkwyX4AAkH5W.jpg',
#     u'sizes': {u'large': {u'h': 1120, u'resize': u'fit', u'w': 840},
#      u'medium': {u'h': 1120, u'resize': u'fit', u'w': 840},
#      u'small': {u'h': 680, u'resize': u'fit', u'w': 510},
#      u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#     u'type': u'photo',
#     u'url': u'https://t.co/8jnQ9gWmur'}],
#   u'retweet_count': 4020,
#   u'source': u'<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   u'urls': [{u'expanded_url': u'http://ti.me/2DLOp0X',
#     u'url': u'https://t.co/Uc9ivXGS2q'}],
#   u'user': {u'created_at': u'Mon Aug 04 15:22:35 +0000 2008',
#    u'description': u"Twitter feed for @TIME's politics channel",
#    u'favourites_count': 31,
#    u'followers_count': 51699,
#    u'friends_count': 766,
#    u'id': 15723290,
#    u'lang': u'en',
#    u'listed_count': 1582,
#    u'name': u'TIMEPolitics',
#    u'profile_background_color': u'CC0000',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/15723290/1403549630',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/481148089399398401/h_6VWChc_normal.jpeg',
#    u'profile_link_color': u'0000FF',
#    u'profile_sidebar_fill_color': u'FFFFFF',
#    u'profile_text_color': u'000000',
#    u'screen_name': u'TIMEPolitics',
#    u'statuses_count': 28224,
#    u'time_zone': u'Eastern Time (US & Canada)',
#    u'url': u'http://t.co/wOYDj1JmLA',
#    u'utc_offset': -18000},
#   u'user_mentions': [{u'id': 14293310,
#     u'name': u'TIME',
#     u'screen_name': u'TIME'},
#    {u'id': 774510134,
#     u'name': u'Charlotte Alter',
#     u'screen_name': u'CharlotteAlter'}]},
#  u'quoted_status_id': 953991903250386944,
#  u'quoted_status_id_str': u'953991903250386944',
#  u'retweet_count': 16057,
#  u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  u'urls': [{u'expanded_url': u'https://twitter.com/timepolitics/status/953991903250386944',
#    u'url': u'https://t.co/vkRj7M3kBS'}],
#  u'user': {u'created_at': u'Tue Apr 09 18:04:35 +0000 2013',
#   u'description': u'Wife, mom, grandma, women+kids advocate, FLOTUS, Senator, SecState, hair icon, pantsuit aficionado, 2016 presidential candidate.',
#   u'favourites_count': 1163,
#   u'followers_count': 21440695,
#   u'friends_count': 770,
#   u'geo_enabled': True,
#   u'id': 1339835893,
#   u'lang': u'en',
#   u'listed_count': 39569,
#   u'location': u'New York, NY',
#   u'name': u'Hillary Clinton',
#   u'profile_background_color': u'0057B8',
#   u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1339835893/1476893928',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/839938827837976576/leN1zJJx_normal.jpg',
#   u'profile_link_color': u'0057B8',
#   u'profile_sidebar_fill_color': u'000000',
#   u'profile_text_color': u'000000',
#   u'screen_name': u'HillaryClinton',
#   u'statuses_count': 10037,
#   u'time_zone': u'Eastern Time (US & Canada)',
#   u'url': u'https://t.co/xhPHAcdCwE',
#   u'utc_offset': -18000,
#   u'verified': True},
#  u'user_mentions': []}

# %%
#printing id and text of tweets
for element in x:
    print element['id']
    print(element['full_text'])
    print('--')
# Out:
# 954430425321046016
# I’m so heartened by all of you. Onward! https://t.co/vkRj7M3kBS
# --
# 953005910930153472
# These words from Dr. King also come to mind today: https://t.co/0qFK3RxBAF
# --
# 952958227825782784
# Beautifully said, @BerniceKing. An important message today and every day. https://t.co/eYJAGc6i2b
# --
# 951895239140298752
# The anniversary of the devastating earthquake 8 years ago is a day to remember the tragedy, honor the resilient people of Haiti, &amp; affirm America’s commitment to helping our neighbors. Instead, we‘re subjected to Trump’s ignorant, racist views of anyone who doesn’t look like him.
# --
# 951651923328987136
# @NancyEMcFadden Nancy has a record of beating the odds - from DC to CA - where she helped Gov Brown do a fantastic job. All who know her are sending strength &amp; love as she faces this latest challenge.  Onward my friend. -H
# --
# 948244463138328577
# Families across America had to start 2018 worried that their kids wouldn’t have health care. Failing to act now shows the true face of Republicans &amp; their donor-driven immoral agenda. You control the Senate agenda @SenateMajLdr. Enough is enough.
# --
# 948244159986651136
# Time to bring CHIP to the Senate floor as promised. This alleged extension until March doesn’t cut it as states freeze enrollment &amp; send out letters warning that coverage will end. This is frightening to parents &amp; wreaks havoc for states. https://t.co/tWtm211w8S
# --
# 947313751992274944
# The Iranian people, especially the young, are protesting for the freedom and future they deserve. I hope their government responds peacefully and supports their hopes.
# --
# 944279653883228160
# Thank you to everyone who has donated to Onward Together in our first year -- we’re only able to support these great groups because of you. Let’s do even more in 2018. Onward!
# --
# 944279421065814016
# Along with @IndivisibleTeam, @ColorOfChange, @EmergeAmerica, @swingleft, and @runforsomething, I know these groups will continue to do the incredible work of making our democracy stronger in 2018, and I'm proud to be on their team.
# --
# 944279114172850177
# And with the help of @collectivepac, 23 African-American candidates have been elected to local, state, and federal offices since August 2016.
# --
# 944278916621066240
# More than 400 students and leaders met last month at the @votolatino Power Summit to share resources and tools for national advocacy.
# --
# 944278786874527744
# The team at @latinovictoryus is working to elect more Latino candidates at every level of government.
# --
# 944278119237681152
# At @alliance4youth, young people are using local organizing to address economic inequality, attacks on voting rights, and more.
# --
# 944277880028237826
# 450 brand-new civic leaders and activists attended the very first @ArenaSummit -- and they're on track to train 5,000 people by the end of 2018.
# --

# %%
# From the docs: "Max id returns results with an ID less than (older than) or equal to the
# specified ID. 
y = api.GetUserTimeline(screen_name="HillaryClinton", count=20, max_id=935706980643147777, include_rts=False)
y = [_.AsDict() for _ in y]

# %%
for element in y:
    print element['id']
    print(element['full_text'])
    print('--')
# Out:
# 933449899487780864
# You go girl! This is important; costs will go up, &amp; powerful companies will get more powerful. We can’t let it slip through the cracks. https://t.co/js4agpzKeS
# --
# 933107180131282944
# And on top of that, you can’t beat a little book signing wardrobe fun.
#
# https://t.co/K8VldCmTC6 https://t.co/9q9sTlpL3I
# --
# 933105980484747264
# And being out on the book tour it has been wonderful to hear from so many people about their activism, their courage, &amp; their resilience.
# https://t.co/LhtTwV7N0d
# --
# 933105682378870784
# Wow. I wasn’t sure how letting my guard down would go...but it’s been cathartic &amp; rewarding. I loved writing this book, &amp; I’m honored to be in such great company on this list!
# https://t.co/rAYpWHzxrJ
# --
# 932746529475055618
# It’s been almost 2 months since Congress let the program that provides health care for 9 million children expire. Call Congress &amp; tell them to reauthorize CHIP now: 202-224-3121 https://t.co/jk1FhOcMp2
# --
# 931292276709580802
# It’s true! I want to join your book club to talk about What Happened &amp; what’s happening...sign up! https://t.co/hmWiCrBgsq
# --
# 931292070312140804
# @BenSPLATT @DearEvanHansen Two friends on a perfect day. Sincerely, me.
# --
# 931167854828883968
# Good. https://t.co/IqanY3F28F
# --
# 930540319606747137
# Being your candidate was the honor of a lifetime. Now it's your turn to #runforsomething: https://t.co/ODzNQEossm
# --
# 930519362158686209
# Looking forward to a great discussion with my friend Dorothy and to a great day @UVA! Tune in:
# https://t.co/L20mjSwhCR https://t.co/02ALVZAAKZ
# --
# 930082055278428160
# Join me live this morning at 9:45am for an important discussion about child &amp; adolescent mental health, focused on solutions for families &amp; communities. #ChildMindSummit
# https://t.co/317gv59kHQ
# --
# 929862099446181888
# Proud of you, Becca!
# https://t.co/xAY3yzdf7f https://t.co/lEo1f5eYDq
# --
# 929749504131289088
# It was a thrill to work on this project with @ElaineWelteroth.  I’m really proud of the result. I hope you enjoy it. https://t.co/MILM8WdvOg
# --

# %%
type(y[0])
# Out:
# dict

# %%
y[0]['id']
# Out:
# 933449899487780864

# %%
#TweetMiner function from Mike Roman

class TweetMiner(object):

    
    def __init__(self, api, result_limit = 20):
        
        self.api = api        
        self.result_limit = result_limit
        

    def mine_user_tweets(self, user="HillaryClinton", mine_retweets=False, max_pages=20):

        data           =  []
        last_tweet_id  =  False
        page           =  1
        
        while page <= max_pages:
            
            if last_tweet_id:
                statuses   =   self.api.GetUserTimeline(screen_name=user, count=self.result_limit, max_id=last_tweet_id - 1, include_rts=mine_retweets)
                statuses = [ _.AsDict() for _ in statuses]
            else:
                statuses   =   self.api.GetUserTimeline(screen_name=user, count=self.result_limit, include_rts=mine_retweets)
                statuses = [_.AsDict() for _ in statuses]
                
            for item in statuses:
                # Using try except here.
                # When retweets = 0 we get an error (GetUserTimeline fails to create a key, 'retweet_count')
                try:
                    mined = {
                        'tweet_id':        item['id'],
                        'handle':          item['user']['screen_name'],
                        'retweet_count':   item['retweet_count'],
                        'text':            item['full_text'],
                        'mined_at':        datetime.datetime.now(),
                        'created_at':      item['created_at'],
                    }
                
                except:
                        mined = {
                        'tweet_id':        item['id'],
                        'handle':          item['user']['screen_name'],
                        'retweet_count':   0,
                        'text':            item['full_text'],
                        'mined_at':        datetime.datetime.now(),
                        'created_at':      item['created_at'],
                    }
                
                last_tweet_id = item['id']
                data.append(mined)
                
            page += 1
            
        return data

# %% [markdown]
# ## Instantiate the class
# ---
#
# Make sure you pass the keys dictionary and the api as arguments.
#
# **Check:** call the object's `mine_user_tweets()` method, providing a user to pull the tweets of.

# %%
# Result limit == count parameter from our GetUserTimeline()
miner = TweetMiner(api, result_limit=200)

# %%
hillary = miner.mine_user_tweets(user="HillaryClinton")
donald = miner.mine_user_tweets(user="realDonaldTrump")

# %%
for x in range(5):
    print hillary[x]['text']
    print('---')
# Out:
# I’m so heartened by all of you. Onward! https://t.co/vkRj7M3kBS
# ---
# These words from Dr. King also come to mind today: https://t.co/0qFK3RxBAF
# ---
# Beautifully said, @BerniceKing. An important message today and every day. https://t.co/eYJAGc6i2b
# ---
# The anniversary of the devastating earthquake 8 years ago is a day to remember the tragedy, honor the resilient people of Haiti, &amp; affirm America’s commitment to helping our neighbors. Instead, we‘re subjected to Trump’s ignorant, racist views of anyone who doesn’t look like him.
# ---
# @NancyEMcFadden Nancy has a record of beating the odds - from DC to CA - where she helped Gov Brown do a fantastic job. All who know her are sending strength &amp; love as she faces this latest challenge.  Onward my friend. -H
# ---

# %%
for x in range(5):
    print donald[x]['text']
    print('--')
# Out:
# Not looking good for our great Military or Safety &amp; Security on the very dangerous Southern Border. Dems want a Shutdown in order to help diminish the great success of the Tax Cuts, and what they are doing for our booming economy.
# --
# Excellent preliminary meeting in Oval with @SenSchumer - working on solutions for Security and our great Military together with @SenateMajLdr McConnell and @SpeakerRyan. Making progress - four week extension would be best!
# --
# Just signed 702 Bill to reauthorize foreign intelligence collection. This is NOT the same FISA law that was so wrongly abused during the election. I will always do the right thing for our country and put the safety of the American people first!
# --
# Today, I was honored and proud to address the 45th Annual @March_for_Life! You are living witnesses of this year’s March for Life theme: #LoveSavesLives. https://t.co/DMST4qhDmp
# --
# “Shutting down the government is a very serious thing. People die, accidents happen. I don’t know how I would vote right now on a CR, OK?”
# Sen. Dianne Feinstein (D-Calif)
# https://t.co/7xP3CBnv5j
# --

# %% [markdown]
# ### Convert the tweet ouputs to a pandas DataFrame

# %%
# A:
pd.DataFrame(hillary)
# Out:
#                           created_at          handle  \
# 0     Fri Jan 19 19:08:40 +0000 2018  HillaryClinton
# 1     Mon Jan 15 20:48:09 +0000 2018  HillaryClinton
# 2     Mon Jan 15 17:38:41 +0000 2018  HillaryClinton
# 3     Fri Jan 12 19:14:45 +0000 2018  HillaryClinton
# 4     Fri Jan 12 03:07:54 +0000 2018  HillaryClinton
# 5     Tue Jan 02 17:27:52 +0000 2018  HillaryClinton
# 6     Tue Jan 02 17:26:39 +0000 2018  HillaryClinton
# 7     Sun Dec 31 03:49:33 +0000 2017  HillaryClinton
# 8     Fri Dec 22 18:53:08 +0000 2017  HillaryClinton
# 9     Fri Dec 22 18:52:12 +0000 2017  HillaryClinton
# 10    Fri Dec 22 18:50:59 +0000 2017  HillaryClinton
# 11    Fri Dec 22 18:50:12 +0000 2017  HillaryClinton
# 12    Fri Dec 22 18:49:41 +0000 2017  HillaryClinton
# 13    Fri Dec 22 18:47:02 +0000 2017  HillaryClinton
# 14    Fri Dec 22 18:46:05 +0000 2017  HillaryClinton
# 15    Fri Dec 22 18:45:12 +0000 2017  HillaryClinton
# 16    Fri Dec 22 18:44:06 +0000 2017  HillaryClinton
# 17    Wed Dec 20 19:51:11 +0000 2017  HillaryClinton
# 18    Wed Dec 20 02:14:53 +0000 2017  HillaryClinton
# 19    Tue Dec 19 22:57:23 +0000 2017  HillaryClinton
# 20    Sat Dec 16 18:47:01 +0000 2017  HillaryClinton
# 21    Sat Dec 16 02:52:31 +0000 2017  HillaryClinton
# 22    Fri Dec 15 21:46:30 +0000 2017  HillaryClinton
# 23    Fri Dec 15 17:46:05 +0000 2017  HillaryClinton
# 24    Thu Dec 14 19:33:00 +0000 2017  HillaryClinton
# 25    Wed Dec 13 05:16:39 +0000 2017  HillaryClinton
# 26    Wed Dec 13 03:32:06 +0000 2017  HillaryClinton
# 27    Wed Dec 13 01:13:20 +0000 2017  HillaryClinton
# 28    Sat Dec 09 00:32:27 +0000 2017  HillaryClinton
# 29    Sat Dec 09 00:31:11 +0000 2017  HillaryClinton
# ...                              ...             ...
# 2537  Tue Jul 26 03:22:21 +0000 2016  HillaryClinton
# 22    Thank you to the @lapromisefund &amp; @msjwill...  941786571837181953
# 23    Today is the final day to sign up for 2018 hea...  941726067638681600
# 24    @ELaffGarb @DHochsprung @ELaffGarb, thinking o...  941390586845597696
# 25      Yes!\nElections matter. https://t.co/xU8dpew1Cn  940812691924496385
# 26    Tonight, Alabama voters elected a senator who'...  940786378069049344
# 27    Mayor Ed Lee’s death is a terrible loss for th...  940751455782391808
# 28    If you don't live in an area that could be aff...  939291618250842112
# 29    Thinking about all affected &amp; those who co...  939291298678362113
# ...                                                 ...                 ...
# 2537  "I served with her in the United States Senate...  757778054815047680
# 2538  "While...Trump is busy insulting one group aft...  757777047523557376
# 2539  "Donald Trump? Well, like most Republicans, he...  757776714273546241
# 2540  “Hillary Clinton will nominate justices to the...  757774948928720896
# 2541  "Hillary...understands that if someone in this...  757774363458433024
# 2542  "Hillary Clinton must become the next presiden...  757773990173806592
# 2543  "We have come a long way in the last 7 1/2 yea...  757773551751598080
# 2544  Happening now: Watch @BernieSanders address th...  757771391093600256
# 2545  "Trump’s entire campaign is just one more, lat...  757769901402681344
# 2546  Couldn’t agree more, @POTUS. https://t.co/hvsf...  757769136269320193
# 2547  “If you believe we are stronger together, then...  757768703521988610
# 2548  “We’re not going to be Donald Trump’s hate-fil...  757767949327400964
# 2549  "When we turn on each other, we can’t unite to...  757767826648231936
# 2550  “That’s Donald Trump’s America—an America of f...  757767359843147776
# 2551  "He even picked a vice president famous for tr...  757767223134093316
# 2552  "Last week...Trump spoke for more than an hour...  757766649474912257
# 2553  "What kind of a man cheats students, cheats in...  757766513013194752
# 2554  "What kind of a man roots for an economic cras...  757766052428312576
# 2555  "He preyed on...people who had fallen on hard ...  757765891908132864
# 2556  Watch @ElizabethForMA live at the #DemConventi...  757764326128283648
# 2557  "Hillary Clinton has never quit on anything in...  757763989359173632
# 2558  "We need to pour every last ounce of our passi...  757762738433191936
# 2559  "Don’t let anyone ever tell you that this coun...  757762395787911168
# 2560  “Because of Hillary Clinton, my daughters…now ...  757762219300052992
# 2561  "Hillary understands that the presidency is ab...  757761430477279232
# 2562  "In this election, I’m with her!" —@FLOTUS on ...  757761359035699200
# 2563  "We don’t turn against each other—no, we liste...  757761152231346176
# 2564  "Hillary Clinton has never quit on anything in...  757760912581419008
# 2565  "When she didn’t win the nomination 8 years ag...  757760436842459137
# 2566  "There is only one person...truly qualified to...  757759935136600064
#
# [2567 rows x 6 columns]

# %% [markdown]
# ##  Create the training data
#
# ---
#
# "Mined" data from the Twitter API.
#
# 1. Mine Trump tweets
# - Create a tweet DataFrame
# - Mine Hillary tweets
# - Append the results to our DataFrame

# %%
# A:
miner = TweetMiner(api, result_limit=200)
trump_tweets = miner.mine_user_tweets("realDonaldTrump", max_pages=14)

# %%
trump_df = pd.DataFrame(trump_tweets)

# %%
trump_df
# Out:
#                           created_at           handle  \
# 0     Sat Jan 20 02:28:56 +0000 2018  realDonaldTrump
# 1     Fri Jan 19 22:17:53 +0000 2018  realDonaldTrump
# 2     Fri Jan 19 20:53:17 +0000 2018  realDonaldTrump
# 2457  Being at the Army - Navy Game was fantastic. T...  807935995316408322
# 2458  I will be interviewed today on Fox News Sunday...  807932020236124160
# 2459  October 2015 - thanks Chris Wallace @FoxNewsSu...  807663477322027008
# 2460  A very interesting read. Unfortunately, so muc...  807589280071684096
# 2461  Reports by @CNN that I will be working on The ...  807588632877998081
# 2462  As a show of support for our Armed Forces, I w...  807565127021109252
# 2463  I have NOTHING to do with The Apprentice excep...  807547249681166336
# 2464  .@RudyGiuliani, one of the finest people I kno...  807545243608420352
# 2465  Thank you Michigan. We are going to bring back...  807427326522884096
# 2466  Thank you Louisiana! Get out &amp; vote for Jo...  807347429062443009
# 2467  Join me live in Louisiana! Tomorrow, we need y...  807309464705630208
# 2468  THANK YOU IOWA!\n#ThankYouTour2016 https://t.c...  807057700857188355
# 2469  Join me tomorrow! #MAGA \n10am- Baton Rouge, L...  806999846674698240
# 2470  On my way to Des Moines, Iowa- will see you so...  806995622117122048
# 2471  Today we lost a great pioneer of air and space...  806970576359325696
# 2472  If United Steelworkers 1999 was any good, they...  806678853305384960
# 2473  Chuck Jones, who is President of United Steelw...  806660011904614408
# 2474  Join me tomorrow in Des Moines, Iowa with Vice...  806583438748815361
# 2475  We pause today to remember the 2,403 American ...  806568460620857349
# 2476  I will be interviewed on the @TODAYshow at 7:3...  806473064703725568
# 2477  A great night in Fayetteville, North Carolina....  806340792247795715
# 2478  Departing New York with General James 'Mad Dog...  806246271405162500
#
# [2479 rows x 6 columns]

# %%
trump_df.shape
# Out:
# (2479, 6)

# %%
hillary_tweets = miner.mine_user_tweets('HillaryClinton')

# %%
hillary_df = pd.DataFrame(hillary_tweets)
print hillary_df.shape
# Out:
# (2567, 6)

# %%
tweets = pd.concat([trump_df, hillary_df], axis=0)
tweets.shape
# Out:
# (5046, 6)

# %% [markdown]
# ## Any interesting ngrams going on with Trump or Hillary?

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter

# We can use the TfidfVectorizer to find ngrams for us
vect = TfidfVectorizer(ngram_range=(2,5), stop_words='english')

# Pulls all of trumps tweet text's into one giant string
summaries = "".join(trump_df['text'])
ngrams_summaries = vect.build_analyzer()(summaries)

Counter(ngrams_summaries).most_common(20)
# Out:
# [(u'fake news', 162),
#  (u'america great', 79),
#  (u'tax cuts', 72),
#  (u'make america', 65),
#  (u'united states', 63),
#  (u'make america great', 59),
#  (u'north korea', 50),
#  (u'news media', 44),
#  (u'white house', 43),
#  (u'great honor', 43),
#  (u'fake news media', 42),
#  (u'stock market', 40),
#  (u'tax cut', 34),
#  (u'working hard', 32),
#  (u'usa https', 31),
#  (u'hillary clinton', 30),
#  (u'puerto rico', 27),
#  (u'prime minister', 27),
#  (u'american people', 27),
#  (u'jobs jobs', 26)]

# %% [markdown]
# ## Fake news....figures

# %%
vect = TfidfVectorizer(ngram_range=(2,5), stop_words='english')

summaries = "".join(hillary_df['text'])
ngrams_summaries = vect.build_analyzer()(summaries)

Counter(ngrams_summaries).most_common(20)
# Out:
# [(u'donald trump', 218),
#  (u'hillary https', 101),
#  (u'https ttgeqxnqym', 88),
#  (u'hillary clinton', 69),
#  (u'vote https', 57),
#  (u'make sure', 52),
#  (u'trump https', 48),
#  (u'ttgeqxnqym https', 47),
#  (u'https ttgeqxnqym https', 47),
#  (u'debatenight https', 47),
#  (u'potus https', 45),
#  (u'https 3tkj4h68kz', 44),
#  (u'president https', 39),
#  (u'https 3tkj4h68kz https', 32),
#  (u'3tkj4h68kz https', 32),
#  (u'united states', 31),
#  (u'flotus https', 30),
#  (u've got', 30),
#  (u'commander chief', 29),
#  (u'donald trump https', 28)]

# %% [markdown]
# ## Processing the tweets and building a model
#
# ---
#
# To do classfication I will need to convert the tweets into a set of features.
#
# **I'll do this by:**
# - Vectorizing input text data.
# - Intializing a model.
# - Grid Searching for optimal hyperparameters.
# - Training and fitting optimized model.
# - Evaluating the performance of the model.

# %%
#cleaning text data using textacy
from textacy.preprocess import preprocess_text

tweet_text = tweets['text'].values
clean_text = [preprocess_text(x, fix_unicode=True, lowercase=True, no_urls=True, no_emails=True, no_phone_numbers=True, no_currency_symbols=True,
                              no_punct=True, no_accents=True)
              for x in tweet_text]

# %%
print tweet_text[1:8]
# Out:
# [ u'Excellent preliminary meeting in Oval with @SenSchumer - working on solutions for Security and our great Military together with @SenateMajLdr McConnell and @SpeakerRyan. Making progress - four week extension would be best!'
#  u'Just signed 702 Bill to reauthorize foreign intelligence collection. This is NOT the same FISA law that was so wrongly abused during the election. I will always do the right thing for our country and put the safety of the American people first!'
#  u'Today, I was honored and proud to address the 45th Annual @March_for_Life! You are living witnesses of this year\u2019s March for Life theme: #LoveSavesLives. https://t.co/DMST4qhDmp'
#  u'\u201cShutting down the government is a very serious thing. People die, accidents happen. I don\u2019t know how I would vote right now on a CR, OK?\u201d\nSen. Dianne Feinstein (D-Calif)\nhttps://t.co/7xP3CBnv5j'
#  u'.@WhiteHouse Briefing with Director Marc Short and Director Mick Mulvaney...\nhttps://t.co/0O0VsYXmHB'
#  u'Government Funding Bill past last night in the House of Representatives. Now Democrats are needed if it is to pass in the Senate - but they want illegal immigration and weak borders. Shutdown coming? We need more Republican victories in 2018!'
#  u'House of Representatives needs to pass Government Funding Bill tonight. So important for our country - our Military needs it!']

# %%
print clean_text[1:8]
# Out:
# [u'excellent preliminary meeting in oval with senschumer working on solutions for security and our great military together with senatemajldr mcconnell and speakerryan making progress four week extension would be best', u'just signed 702 bill to reauthorize foreign intelligence collection this is not the same fisa law that was so wrongly abused during the election i will always do the right thing for our country and put the safety of the american people first', u'today i was honored and proud to address the 45th annual marchforlife you are living witnesses of this years march for life theme lovesaveslives url', u'shutting down the government is a very serious thing people die accidents happen i dont know how i would vote right now on a cr ok\nsen dianne feinstein dcalif\nurl', u'whitehouse briefing with director marc short and director mick mulvaney\nurl', u'government funding bill past last night in the house of representatives now democrats are needed if it is to pass in the senate but they want illegal immigration and weak borders shutdown coming we need more republican victories in 2018', u'house of representatives needs to pass government funding bill tonight so important for our country our military needs it']

# %%
#creating target
y = tweets['handle'].map(lambda x: 1 if x == 'realDonaldTrump' else 0).values
print max(pd.Series(y).value_counts(normalize=True))
# Out:
# 0.508719778042

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC


#Vectorizing with TF-IDF Vectorizer and creating X matrix
tfv = TfidfVectorizer(ngram_range=(2,4), max_features=2000)
X = tfv.fit_transform(clean_text).todense()
print X.shape
# Out:
# (5046, 2000)

# %%
from sklearn.model_selection import GridSearchCV

lr = LogisticRegression()
params = {'penalty': ['l1', 'l2'], 'C':np.logspace(-5,0,100)}
#Grid searching to find optimal parameters for Logistic Regression
gs = GridSearchCV(lr, param_grid=params, cv=10, verbose=1)
gs.fit(X, y)
# Out:
# Fitting 10 folds for each of 200 candidates, totalling 2000 fits
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:  2.2min finished
# GridSearchCV(cv=10, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'penalty': ['l1', 'l2'], 'C': array([  1.00000e-05,   1.12332e-05, ...,   8.90215e-01,   1.00000e+00])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1)

# %%
print gs.best_params_
print gs.best_score_
# Out:
# {'penalty': 'l2', 'C': 1.0}
# 0.85037653587

# %% [markdown]
# ## I tried Grid Searching over KNN hyperparameters but after 20 minutes it still wasn't done searching over the 120 fits I gave it. Such is life.

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(LogisticRegression(), X, y, cv=10)

print accuracies.mean()
print 1-y.mean()
# Out:
# 0.850353449006
# 0.508719778042

# %% [markdown]
# ## Check the predicted probability for a random Sanders and Trump tweet
# ---
#
# Below are provided a couple of tweets from both Hillary and Trump.

# %%
estimator = LogisticRegression(penalty='l2',C=1.0)
estimator.fit(X,y)

# Prep our source as TfIdf vectors
source_test = [
    "The presidency doesn’t change who you are—it reveals who you are. And we’ve seen all we need to of Donald Trump.",
    "Crooked Hillary is spending tremendous amounts of Wall Street money on false ads against me. She is a very dishonest person!"
]

###
# NOTE:  Do not re-initialize the tfidf vectorizor or the feature space will be overwritten and
# your transform will not match the number of features you trained your model on.
#
# This is why you only need to "transform" since you already "fit" previously
#
####

Xtest = tfv.transform(source_test)
pd.DataFrame(estimator.predict_proba(Xtest), columns=["Proba_Hillary", "Proba_Trump"])
# Out:
#    Proba_Hillary  Proba_Trump
# 0       0.899186     0.100814
# 1       0.313876     0.686124

# %% [markdown]
# So based on the model, the probablility the first tweet came from Hillary is almost 90%! The probability the second tweet came from Trump is almost 70%. So I would say the model is performing pretty well.

# %% [markdown]
# ## Now I'm going to to attempt to extract the tweets that have the highest and lowest probability of being from Trump or Hillary based on the model.
# ---
# **I'm going to do this by:**
# 1. Using the Predict Proba method to give me an array of the probabilites of Hillary and Trump tweets
# - Transform that array into a dataframe
# - Merge the tweets datafram and probability dataframe
# - Filter and create dataframe with only tweets of either person
# - Use a list comprehension to print out the highest and lowest probability tweets

# %%
estimator.predict_proba(X)
# Out:
# array([[ 0.0759295 ,  0.9240705 ],
#        [ 0.21657961,  0.78342039],
#        [ 0.39374219,  0.60625781],
#        ...,
#        [ 0.79698732,  0.20301268],
#        [ 0.58901552,  0.41098448],
#        [ 0.71431185,  0.28568815]])

# %%
Probas_x = pd.DataFrame(estimator.predict_proba(X), columns=["Proba_Hillary", "Proba_Donald"])

# %%
joined_x = pd.merge(tweets, Probas_x, left_index=True, right_index=True)

# %%
joined_x
# Out:
#                           created_at           handle  \
# 0     Sat Jan 20 02:28:56 +0000 2018  realDonaldTrump
# 0     Fri Jan 19 19:08:40 +0000 2018   HillaryClinton
# 1     Fri Jan 19 22:17:53 +0000 2018  realDonaldTrump
# 1     Mon Jan 15 20:48:09 +0000 2018   HillaryClinton
# 2     Fri Jan 19 20:53:17 +0000 2018  realDonaldTrump
# 2     Mon Jan 15 17:38:41 +0000 2018   HillaryClinton
# 3     Fri Jan 19 18:39:50 +0000 2018  realDonaldTrump
# 3     Fri Jan 12 19:14:45 +0000 2018   HillaryClinton
# 4     Fri Jan 19 16:28:29 +0000 2018  realDonaldTrump
# 4     Fri Jan 12 03:07:54 +0000 2018   HillaryClinton
# 5     Fri Jan 19 16:14:05 +0000 2018  realDonaldTrump
# 5     Tue Jan 02 17:27:52 +0000 2018   HillaryClinton
# 6     Fri Jan 19 12:04:47 +0000 2018  realDonaldTrump
# 6     Tue Jan 02 17:26:39 +0000 2018   HillaryClinton
# 7     Thu Jan 18 23:39:53 +0000 2018  realDonaldTrump
# 7     Sun Dec 31 03:49:33 +0000 2017   HillaryClinton
# 8     Thu Jan 18 21:04:36 +0000 2018  realDonaldTrump
# 8     Fri Dec 22 18:53:08 +0000 2017   HillaryClinton
# 9     Thu Jan 18 20:45:33 +0000 2018  realDonaldTrump
# 9     Fri Dec 22 18:52:12 +0000 2017   HillaryClinton
# 10    Thu Jan 18 13:49:11 +0000 2018  realDonaldTrump
# 10    Fri Dec 22 18:50:59 +0000 2017   HillaryClinton
# 11    Thu Jan 18 13:37:24 +0000 2018  realDonaldTrump
# 11    Fri Dec 22 18:50:12 +0000 2017   HillaryClinton
# 12    Thu Jan 18 13:16:26 +0000 2018  realDonaldTrump
# 12    Fri Dec 22 18:49:41 +0000 2017   HillaryClinton
# 13    Thu Jan 18 12:53:17 +0000 2018  realDonaldTrump
# 13    Fri Dec 22 18:47:02 +0000 2017   HillaryClinton
# 14    Thu Jan 18 11:25:03 +0000 2018  realDonaldTrump
# 14    Fri Dec 22 18:46:05 +0000 2017   HillaryClinton
# ...                              ...              ...
# 2537  Tue Jul 26 03:22:21 +0000 2016   HillaryClinton
# 2538  Tue Jul 26 03:18:21 +0000 2016   HillaryClinton
# 2539  Tue Jul 26 03:17:02 +0000 2016   HillaryClinton
# 2540  Tue Jul 26 03:10:01 +0000 2016   HillaryClinton
# 2541  Tue Jul 26 03:07:41 +0000 2016   HillaryClinton
# 2542  Tue Jul 26 03:06:12 +0000 2016   HillaryClinton
# 2543  Tue Jul 26 03:04:28 +0000 2016   HillaryClinton
# 2544  Tue Jul 26 02:55:53 +0000 2016   HillaryClinton
# 2545  Tue Jul 26 02:49:57 +0000 2016   HillaryClinton
# 2546  Tue Jul 26 02:46:55 +0000 2016   HillaryClinton
# 2547  Tue Jul 26 02:45:12 +0000 2016   HillaryClinton
# 2548  Tue Jul 26 02:42:12 +0000 2016   HillaryClinton
# 2549  Tue Jul 26 02:41:43 +0000 2016   HillaryClinton
# 2550  Tue Jul 26 02:39:51 +0000 2016   HillaryClinton
# 2551  Tue Jul 26 02:39:19 +0000 2016   HillaryClinton
# 2552  Tue Jul 26 02:37:02 +0000 2016   HillaryClinton
# 2553  Tue Jul 26 02:36:29 +0000 2016   HillaryClinton
# 2554  Tue Jul 26 02:34:40 +0000 2016   HillaryClinton
# 2555  Tue Jul 26 02:34:01 +0000 2016   HillaryClinton
# 2556  Tue Jul 26 02:27:48 +0000 2016   HillaryClinton
# 2557  Tue Jul 26 02:26:28 +0000 2016   HillaryClinton
# 2559 2018-01-20 01:32:23.829727           5081
# 2560 2018-01-20 01:32:23.829730           4801
# 2561 2018-01-20 01:32:23.829734           2552
# 2562 2018-01-20 01:32:23.829737           1893
# 2563 2018-01-20 01:32:23.829741           2219
# 2564 2018-01-20 01:32:23.829745           1496
# 2565 2018-01-20 01:32:23.829748           3985
# 2566 2018-01-20 01:32:23.829752           2453
#
#                                                    text            tweet_id  \
# 0     Not looking good for our great Military or Saf...  954541219970977793
# 0     I’m so heartened by all of you. Onward! https:...  954430425321046016
# 1     Excellent preliminary meeting in Oval with @Se...  954478044487520257
# 1     These words from Dr. King also come to mind to...  953005910930153472
# 2     Just signed 702 Bill to reauthorize foreign in...  954456754137501697
# 2     Beautifully said, @BerniceKing. An important m...  952958227825782784
# 3     Today, I was honored and proud to address the ...  954423170299199488
# 3     The anniversary of the devastating earthquake ...  951895239140298752
# 4     “Shutting down the government is a very seriou...  954390114968498176
# 4     @NancyEMcFadden Nancy has a record of beating ...  951651923328987136
# 5     .@WhiteHouse Briefing with Director Marc Short...  954386490842378241
# 5     Families across America had to start 2018 worr...  948244463138328577
# 6     Government Funding Bill past last night in the...  954323750949982208
# 6     Time to bring CHIP to the Senate floor as prom...  948244159986651136
# 7     House of Representatives needs to pass Governm...  954136290768846850
# 7     The Iranian people, especially the young, are ...  947313751992274944
# 8     AMERICA will once again be a NATION that think...  954097213608570880
# 8     Thank you to everyone who has donated to Onwar...  944279653883228160
# 9     Departing Pittsburgh now, where it was my grea...  954092417250222082
# 9     Along with @IndivisibleTeam, @ColorOfChange, @...  944279421065814016
# 10    A government shutdown will be devastating to o...  953987636057821184
# 10    And with the help of @collectivepac, 23 Africa...  944279114172850177
# 11    CHIP should be part of a long term solution, n...  953984671674662912
# 11    More than 400 students and leaders met last mo...  944278916621066240
# 12    We need the Wall for the safety and security o...  953979393180950528
# 12    The team at @latinovictoryus is working to ele...  944278786874527744
# 13    Will be going to Pennsylvania today in order t...  953973568035086336
# 13    At @alliance4youth, young people are using loc...  944278119237681152
# 14    ....The Wall will be paid for, directly or ind...  953951365532876800
# 14    450 brand-new civic leaders and activists atte...  944277880028237826
# ...                                                 ...                 ...
# 2537  "I served with her in the United States Senate...  757778054815047680
# 2538  "While...Trump is busy insulting one group aft...  757777047523557376
# 2539  "Donald Trump? Well, like most Republicans, he...  757776714273546241
# 2540  “Hillary Clinton will nominate justices to the...  757774948928720896
# 2541  "Hillary...understands that if someone in this...  757774363458433024
# 2542  "Hillary Clinton must become the next presiden...  757773990173806592
# 2543  "We have come a long way in the last 7 1/2 yea...  757773551751598080
# 2544  Happening now: Watch @BernieSanders address th...  757771391093600256
# 2545  "Trump’s entire campaign is just one more, lat...  757769901402681344
# 2546  Couldn’t agree more, @POTUS. https://t.co/hvsf...  757769136269320193
# 2547  “If you believe we are stronger together, then...  757768703521988610
# 2548  “We’re not going to be Donald Trump’s hate-fil...  757767949327400964
# 2549  "When we turn on each other, we can’t unite to...  757767826648231936
# 2550  “That’s Donald Trump’s America—an America of f...  757767359843147776
# 2551  "He even picked a vice president famous for tr...  757767223134093316
# 2552  "Last week...Trump spoke for more than an hour...  757766649474912257
# 2553  "What kind of a man cheats students, cheats in...  757766513013194752
# 2554  "What kind of a man roots for an economic cras...  757766052428312576
# 2555  "He preyed on...people who had fallen on hard ...  757765891908132864
# 2556  Watch @ElizabethForMA live at the #DemConventi...  757764326128283648
# 2557  "Hillary Clinton has never quit on anything in...  757763989359173632
# 2558  "We need to pour every last ounce of our passi...  757762738433191936
# 2559  "Don’t let anyone ever tell you that this coun...  757762395787911168
# 2560  “Because of Hillary Clinton, my daughters…now ...  757762219300052992
# 2561  "Hillary understands that the presidency is ab...  757761430477279232
# 2562  "In this election, I’m with her!" —@FLOTUS on ...  757761359035699200
# 2563  "We don’t turn against each other—no, we liste...  757761152231346176
# 2564  "Hillary Clinton has never quit on anything in...  757760912581419008
# 2565  "When she didn’t win the nomination 8 years ag...  757760436842459137
# 2566  "There is only one person...truly qualified to...  757759935136600064
#
#       Proba_Hillary  Proba_Donald
# 0          0.075930      0.924070
# 0          0.075930      0.924070
# 1          0.216580      0.783420
# 1          0.216580      0.783420
# 2          0.393742      0.606258
# 2          0.393742      0.606258
# 3          0.632004      0.367996
# 3          0.632004      0.367996
# 4          0.331828      0.668172
# 4          0.331828      0.668172
# 5          0.540637      0.459363
# 5          0.540637      0.459363
# 6          0.131871      0.868129
# 6          0.131871      0.868129
# 7          0.455126      0.544874
# 7          0.455126      0.544874
# 8          0.262080      0.737920
# 8          0.262080      0.737920
# 9          0.115448      0.884552
# 9          0.115448      0.884552
# 10         0.044141      0.955859
# 10         0.044141      0.955859
# 11         0.602060      0.397940
# 11         0.602060      0.397940
# 12         0.135037      0.864963
# 12         0.135037      0.864963
# 13         0.111002      0.888998
# 13         0.111002      0.888998
# 14         0.032925      0.967075
# 14         0.032925      0.967075
# ...             ...           ...
# 2537       0.551781      0.448219
# 2538       0.429951      0.570049
# 2539       0.483098      0.516902
# 2540       0.828362      0.171638
# 2541       0.521009      0.478991
# 2542       0.586321      0.413679
# 2543       0.744015      0.255985
# 2544       0.540637      0.459363
# 2545       0.178168      0.821832
# 2546       0.734086      0.265914
# 2547       0.540637      0.459363
# 2548       0.865495      0.134505
# 2549       0.829229      0.170771
# 2550       0.738669      0.261331
# 2551       0.860482      0.139518
# 2552       0.623102      0.376898
# 2553       0.540637      0.459363
# 2554       0.706601      0.293399
# 2555       0.677088      0.322912
# 2556       0.797530      0.202470
# 2557       0.614771      0.385229
# 2558       0.762007      0.237993
# 2559       0.695428      0.304572
# 2560       0.776927      0.223073
# 2561       0.547562      0.452438
# 2562       0.507462      0.492538
# 2563       0.786145      0.213855
# 2564       0.485150      0.514850
# 2565       0.671538      0.328462
# 2566       0.619879      0.380121
#
# [5046 rows x 8 columns]

# %%
joined_hillary = joined_x[joined_x['handle']=="HillaryClinton"]
for el in joined_hillary[joined_hillary['Proba_Hillary']==max(joined_hillary['Proba_Hillary'])]['text']:
    print el
# Out:
# "She is the best qualified person for this moment in history." —@BillClinton on Hillary
# https://t.co/WkYfkT9MqX

# %%
for el in joined_hillary[joined_hillary['Proba_Hillary']==min(joined_hillary['Proba_Hillary'])]['text']:
    print el
# Out:
# In just 3 days, we have the chance to make history:
#
# Join Hillary live in Florida as she gets out the vote: https://t.co/oa4NZ1hEHU

# %%
joined_donald = joined_x[joined_x['handle']=="realDonaldTrump"]
for el in joined_donald[joined_donald['Proba_Donald']==max(joined_donald['Proba_Donald'])]['text']:
    print el
# Out:
# ObamaCare premiums are going up, up, up, just as I have been predicting for two years. ObamaCare is OWNED by the Democrats, and it is a disaster. But do not worry. Even though the Dems want to Obstruct, we will Repeal &amp; Replace right after Tax Cuts!

# %%
for el in joined_donald[joined_donald['Proba_Donald']==min(joined_donald['Proba_Donald'])]['text']:
    print el
# Out:
# Heed the advice of @FLGovScott!
#
# "If you're in an evacuation zone, you need to get to a shelter...there's not many hours left." Gov. Scott https://t.co/92W8ViNMUK

# %% [markdown]
# ## Pull tweets for some new users.
#
# Now that we've seen that the model works pretty well with the Trump and Hillary tweets, I'm going to pull some of the tweets of my former collegues at The Tab Media Inc. Namely Amanda Ross, Una Dabiero, Josh Kaplan, and Matt McDonald. I'm going to compare their tweets just like I did Trump and Hillary.

# %% [markdown]
# ## First, it's Amanda and Una's turn. I'm repeatin the same process I used for Trump and Hillary.

# %%
x = api.GetUserTimeline(screen_name="una_dab", count=20, include_rts=False)
x = [_.AsDict() for _ in x]

# %%
x[0]
# Out:
# {u'created_at': u'Sat Jan 20 02:17:07 +0000 2018',
#  u'favorite_count': 1,
#  u'full_text': u'Also him: \u201cI like \u2018Motorsport\u2019\u201d',
#  u'hashtags': [],
#  u'id': 954538246897389568,
#  u'id_str': u'954538246897389568',
#  u'in_reply_to_screen_name': u'una_dab',
#  u'in_reply_to_status_id': 954538036657868800,
#  u'in_reply_to_user_id': 958603717,
#  u'lang': u'en',
#  u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  u'urls': [],
#  u'user': {u'created_at': u'Mon Nov 19 21:26:15 +0000 2012',
#   u'description': u'just a paranoid virgo \u264d\ufe0f \u2022 i write for @babedotnet \u2022',
#   u'favourites_count': 5607,
#   u'followers_count': 368,
#   u'following': True,
#   u'friends_count': 397,
#   u'id': 958603717,
#   u'lang': u'en',
#   u'listed_count': 1,
#   u'name': u'Una Dabiero',
#   u'profile_background_color': u'000000',
#   u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/958603717/1489491657',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/950767690301497347/vpQIURZ6_normal.jpg',
#   u'profile_link_color': u'F5ABB5',
#   u'profile_sidebar_fill_color': u'000000',
#   u'profile_text_color': u'000000',
#   u'screen_name': u'una_dab',
#   u'statuses_count': 4514},
#  u'user_mentions': []}

# %%
for element in x:
    print element['id']
    print(element['full_text'])
    print('--')
# Out:
# 954538246897389568
# Also him: “I like ‘Motorsport’”
# --
# 954538036657868800
# today my dad told me he “likes that guy Gucci Mane” so I’m gonna go kill myself
# --
# 954389341220102145
# how?!??? why??!?? https://t.co/mPnxfsfZjH
# --
# 954105154340622337
# trendy!!!!!! https://t.co/xDq403aujt
# --
# 953706030256533504
# -@realJoeCalder
# --
# 953705538407337985
# Seen in a Bushwick bookstore: https://t.co/2zCcpaa5md
# --
# 953606233868722176
# Facebook reminds me everyday to never feel THAT good about myself https://t.co/sw8m3re0nK
# --
# 953338055192207360
# NEW content FUN times WOw https://t.co/hwMcE5ZTCy
# --
# 952970600435331072
# TW/CW: victim-blaming
# This is why we need a cultural change, now. https://t.co/lFRr2ZJpEI
# --
# 952953619502059520
# Just a normal day at https://t.co/1o7dzK5Llp!! https://t.co/6LAbIJcGBF
# --
# 952937480768118785
# @thecolorhannah Hey Hannah, I'm a writer at @babedotnet. I read your #MeToo story and would really appreciate talking about your experience - its hauntingly relatable and so important. dm me!
# --

# %%
y = api.GetUserTimeline(screen_name="itsamandaross", count=20, max_id=935706980643147777, include_rts=False)
y = [_.AsDict() for _ in y]

# %%
for element in y:
    print element['id']
    print(element['full_text'])
    print('--')
# Out:
# 935675057816383489
# Give me this level of confidence and entitlement pls lmaooo https://t.co/uOFdBFqEGh
# --
# 935524157411995648
# current mood: third-class passenger trapped in the hull of the titanic as it sank https://t.co/9uIZh5ITFB
# --
# 935521727869804545
# another year gone by https://t.co/D5vW4Mpuw4
# --
# 935504294702473218
# Whomst snitched https://t.co/GNOaN2zalD
# --
# 935313039275982848
# Just listened to Ashlee Simpson’s Pieces of Me and now I’m sad and hope I die in my sleep https://t.co/hx1C2vpXjY
# --
# 934969391481020416
# What did this little bitch just call me https://t.co/AmoEwmU7X0
# --
# 934958900822016001
# Well he looks dead https://t.co/fMpd24F1PU
# --
# 934908130659569665
# @DixPeyton Just give in
# --
# 934886215073128448
# If anyone is playing Pocket Camp, PLEASE ADD ME I NEED TO GIVE KUDOS!!!!! https://t.co/8idiyCqK85
# --
# 934817432312729601
# The crackheads in Brooklyn are more powerful than the ones in my neighborhood
# --
# 934648855806775298
# @mattjpfmcdonald @ABC Ok so you can do this but you can’t text me back
# --
# 934601048039272449
# Life update: I poured five Tecates into a water bottle and bumping to It Wasn’t Me in a $30 Uber https://t.co/rUn6F1Cizv
# --
# 934600524174852096
# @torimccue_ We were legit 12 and feeling broken lmao
# --
# 934575093061210113
# Why did I FEEEEEL Lips of an Angel so hard in sixth grade lmao who hurt me????
# --
# 934565543205658624
# Sometimes I think I deserve a book deal and then I remember I’m illiterate
# --
# 934562840345759746
# I used to go to church and now I can’t even read like wow life is crazy
# --

# %%
una = miner.mine_user_tweets(user="una_dab")
amanda = miner.mine_user_tweets(user="itsamandaross")

# %%
for x in range(5):
    print una[x]['text']
    print('---')
# Out:
# Also him: “I like ‘Motorsport’”
# ---
# today my dad told me he “likes that guy Gucci Mane” so I’m gonna go kill myself
# ---
# how?!??? why??!?? https://t.co/mPnxfsfZjH
# ---
# trendy!!!!!! https://t.co/xDq403aujt
# ---
# -@realJoeCalder
# ---

# %%
for x in range(5):
    print amanda[x]['text']
    print('--')
# Out:
# @internest_the Kim: https://t.co/nTlswKbVuy
# --
# @Its_dean @internest_the counterpoint: y'all should just fall in a volcano and die
# --
# why is this a promoted tweet on my TL lol https://t.co/lPazdIzhWc
# --
# @BomptonBrotha88 honestly yeah youre right i think it's like .025/7
# --
# @TracieMorrissey @elenimitzali There's an EIC of the parent company. Eleni and I are the top-line editors at babe that make the final decisions.
# 20    Guy sends me a link to a forum thread in which...  952639106772815873
# 21    @HeadCaseLifeNYC Oh you mean like this? https:...  952630500333678595
# 22    This thread (last tweet!) is not to argue  abo...  952613304781983745
# 23    As the editor of @babedotnet, I’m not a judge,...  952612434958831618
# 24    We had no reason to believe so. Aziz has the c...  952611739010523136
# 25    Especially when a source wants to say anonymou...  952611054588227584
# 26    The incredible @k80way did the bulk of the wor...  952610542472048640
# 27    We had meeting after meeting in which we discu...  952609841717170176
# 28    -We reached out to several members of Aziz’s t...  952609177402335233
# 29    -Read every text she sent to her friends that ...  952608559350591489
# ...                                                 ...                 ...
# 1633         Wholesome TX memes https://t.co/fteZ7CjWxY  823714825482158080
# 1634  Why do I only hang out w janky ass people http...  823279219677466625
# 1635    @LesleyVWarren good, we need to punish them all  823230137986646019
# 1636  tag yourself, i'm a bratty emo money lover htt...  823216478757470208
# 1637       Friendly bodega guys make the world go round  823182311751634944
# 1638  @Mr_Rumpels oooooh buuurn https://t.co/wCLZM1Nf6E  822945765916086274
# 1639                             Cats like plain crisps  822932779730169856
# 1640  There is a v palpable energy to today and I ha...  822811116095045633
# 1641     Ya, it's just science  https://t.co/5EDhfkB0Vf  822762910019620864
# 1642  WHAT DO MY DREAMS MEAN, HELP ME UNIVERSE 😩 ht...  822754509357285377
# 1643  Just dreamt I got told off at work so hard I s...  822753800251461632
# 1644                Big mood ⚡️ https://t.co/1FcHpjQL9V  822673332969635840
# 1645  Ooooh well done, Austin TX ⭐ https://t.co/GTOA...  822672221822943234
# 1646  @RichardBSpencer @draknats Truly an American h...  822650180050763776
# 1647  Hey @RichardBSpencer come to Harlem so I can b...  822649675933249539
# 1648  THIS IS MELANIA TRUMP'S REAL TWITTER BANNER IM...  822643660315619334
# 1649     KNUCK IF U BUCK, BITCH https://t.co/q1XzZKh3Xs  822603234921562113
# 1650  dad come back we miss u :( https://t.co/gYsdx7...  822598457290616832
# 1651  Awesome footage of D.C. cops pepper spraying s...  822566141658824704
# 1652  The Slenderman documentary is out this Monday!...  822286369267519492
# 1653  TBT to when I left the Louvre after 45 minutes...  822275025537474560
# 1654           Honestly I would just be the cutest wife  822259908280205312
# 1655  Andy's post-makeover fashion montage in The De...  822252876412162048
# 1656  can’t wait to make my next small beauty purcha...  822178311338160129
# 1657  Had a nightmare that I was boarding a plane to...  822110068728532993
# 1658    Worst part of being sick is feeling useless tbh  821898168417878016
# 1659               Worse 😊😊😊 https://t.co/ZfbMq4mTYL  821816187369623553
# 1660  Deadly combo of cough medicine, Real Housewive...  821809794491224064
# 1661  Will this hydrocodone cough syrup make me a be...  821725582480338944
# 1662                  @szangani https://t.co/EFCeQMnpRc  821336835188228096
#
# [1663 rows x 6 columns]

# %%
tweets1 = pd.concat([una_tweets, amanda_tweets], axis=0)
tweets1.shape
# Out:
# (2682, 6)

# %% [markdown]
# ## Check out these n-grams. T Swift right at the top for Amanda. #shocking

# %%
# We can use the TfidfVectorizer to find ngrams for us
vect = TfidfVectorizer(ngram_range=(2,5), stop_words='english')

# Pulls all of Una's tweet text's into one giant string
summaries = "".join(una_tweets['text'])
ngrams_summaries = vect.build_analyzer()(summaries)

Counter(ngrams_summaries).most_common(20)
# Out:
# [(u'jcalder93 https', 11),
#  (u'chapel hill', 8),
#  (u'lt lt', 8),
#  (u'social media', 8),
#  (u'foram_491 https', 6),
#  (u'high school', 5),
#  (u'look like', 5),
#  (u'dom_less bubbaprog', 5),
#  (u'gt gt', 4),
#  (u'feel like', 4),
#  (u'lt lt lt', 4),
#  (u'ya know', 4),
#  (u'dom_less byrontau', 4),
#  (u'makes sad', 4),
#  (u'itsamandaross https', 4),
#  (u'https 1o7dzk5llp', 4),
#  (u'yr old', 3),
#  (u'like https', 3),
#  (u'just want', 3),
#  (u'plus sized', 3)]

# %%
vect = TfidfVectorizer(ngram_range=(2,4), stop_words='english')

summaries = "".join(amanda_tweets['text'])
ngrams_summaries = vect.build_analyzer()(summaries)

Counter(ngrams_summaries).most_common(20)
# Out:
# [(u'taylor swift', 21),
#  (u'reputation tonight', 14),
#  (u'reputation tonight reputation', 13),
#  (u'tonight reputation', 13),
#  (u'reputation tonight reputation tonight', 12),
#  (u'tonight reputation tonight', 12),
#  (u'tonight reputation tonight reputation', 12),
#  (u'white people', 10),
#  (u'gospursgo gospursgo', 10),
#  (u'brand new', 10),
#  (u'feel like', 9),
#  (u'gospursgo gospursgo gospursgo', 9),
#  (u'like https', 8),
#  (u'oh god', 8),
#  (u'gospursgo gospursgo gospursgo gospursgo', 8),
#  (u'lol https', 7),
#  (u'just wanna', 7),
#  (u'fuck https', 6),
#  (u'mood https', 6),
#  (u'look like', 6)]

# %%
tweet_text1 = tweets1['text'].values
clean_text1 = [preprocess_text(x, fix_unicode=True, lowercase=True, no_urls=True, no_emails=True, no_phone_numbers=True, no_currency_symbols=True,
                              no_punct=True, no_accents=True)
              for x in tweet_text1]

# %%
print tweet_text1[1:8]
# Out:
# [ u'today my dad told me he \u201clikes that guy Gucci Mane\u201d so I\u2019m gonna go kill myself'
#  u'how?!??? why??!?? https://t.co/mPnxfsfZjH'
#  u'trendy!!!!!! https://t.co/xDq403aujt' u'-@realJoeCalder'
#  u'Seen in a Bushwick bookstore: https://t.co/2zCcpaa5md'
#  u'Facebook reminds me everyday to never feel THAT good about myself https://t.co/sw8m3re0nK'
#  u'NEW content FUN times WOw https://t.co/hwMcE5ZTCy']

# %%
print clean_text1[1:8]
# Out:
# [u'today my dad told me he likes that guy gucci mane so im gonna go kill myself', u'how why url', u'trendy url', u'realjoecalder', u'seen in a bushwick bookstore url', u'facebook reminds me everyday to never feel that good about myself url', u'new content fun times wow url']

# %%
y1 = tweets1['handle'].map(lambda x: 1 if x == 'itsamandaross' else 0).values
print max(pd.Series(y1).value_counts(normalize=True))
# Out:
# 0.620059656972

# %%
tfv = TfidfVectorizer(ngram_range=(1,4), max_features=2000)
X1 = tfv.fit_transform(clean_text1).todense()
print X1.shape
# Out:
# (2682, 2000)

# %%
lr1 = LogisticRegression()
params1 = {'penalty': ['l1', 'l2'], 'C':np.logspace(-5,0,100)}
#Grid searching to find optimal parameters for Logistic Regression
gs_1 = GridSearchCV(lr1, param_grid=params1, cv=10, verbose=1)
gs_1.fit(X1, y1)
# Out:
# Fitting 10 folds for each of 200 candidates, totalling 2000 fits
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:  1.4min finished
# GridSearchCV(cv=10, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'penalty': ['l1', 'l2'], 'C': array([  1.00000e-05,   1.12332e-05, ...,   8.90215e-01,   1.00000e+00])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1)

# %%
print gs_1.best_params_
print gs_1.best_score_
# Out:
# {'penalty': 'l2', 'C': 1.0}
# 0.752796420582

# %% [markdown]
# **Still a pretty decent score.**

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

accuracies = cross_val_score(LogisticRegression(), X1, y1, cv=10, verbose=1)

print accuracies.mean()
print y.mean()
# Out:
# 0.752840128749
# 0.491280221958
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.6s finished

# %%
estimator = LogisticRegression()
estimator.fit(X1,y1)

source_test = [
    "My new skincare routine makes me wanna run a marathon, save the elephants, and drink 8 gallons of water all at the same time",
    "I just wanna know what the fuck happened last night between the hours of 5 pm and 5 am"
]

Xtest = tfv.transform(source_test)
pd.DataFrame(estimator.predict_proba(Xtest), columns=["Proba_Una", "Proba_Amanda"])
# Out:
#    Proba_Una  Proba_Amanda
# 0   0.594196      0.405804
# 1   0.354655      0.645345

# %%
# A:
estimator.predict_proba(X1)
# Out:
# array([[ 0.23455396,  0.76544604],
#        [ 0.30520921,  0.69479079],
#        [ 0.48281644,  0.51718356],
#        ...,
#        [ 0.17327266,  0.82672734],
#        [ 0.40098317,  0.59901683],
#        [ 0.23242993,  0.76757007]])

# %%
Probas = pd.DataFrame(estimator.predict_proba(X1), columns=["Proba_Una", "Proba_Amanda"])

# %%
joined = pd.merge(tweets1, Probas, left_index=True, right_index=True)

# %%
joined.head(2)
# Out:
#                        created_at         handle                   mined_at  \
# 0  Sat Jan 20 02:17:07 +0000 2018        una_dab 2018-01-20 01:56:42.231974
# 0  Thu Jan 18 22:00:47 +0000 2018  itsamandaross 2018-01-20 01:56:49.213123
#
#    retweet_count                                         text  \
# 0              0              Also him: “I like ‘Motorsport’”
# 0              0  @internest_the Kim: https://t.co/nTlswKbVuy
#
#              tweet_id  Proba_Una  Proba_Amanda
# 0  954538246897389568   0.234554      0.765446
# 0  954111353911988224   0.234554      0.765446

# %%
joined_una = joined[joined['handle']=="una_dab"]
for el in joined_una[joined_una['Proba_Una']==max(joined_una['Proba_Una'])]['text']:
    print el
# Out:
# @foram_491 Facts
# @foram_491 💁🏼💁🏼💁🏼
# @foram_491 phew
# @foram_491 😢😇

# %%
for el in joined_una[joined_una['Proba_Una']==min(joined_una['Proba_Una'])]['text']:
    print el
# Out:
# my element https://t.co/pgK6npXrrU

# %%
joined_amanda = joined[joined['handle']=="itsamandaross"]
for el in joined_amanda[joined_amanda['Proba_Amanda']==max(joined_amanda['Proba_Amanda'])]['text']:
    print el
# Out:
# Friendly bodega guys make the world go round

# %%
for el in joined_amanda[joined_amanda['Proba_Amanda']==min(joined_amanda['Proba_Amanda'])]['text']:
    print el
# Out:
# I’ll know I actually like a guy when I wash my hair before a date
# I'm so tired of art hoes https://t.co/cZMptQVCNI
# I think what I really want is to marry like a hot earth scientist
# U ever take a shower so hot it strips you of all ur sins plus ur top layer of skin

# %% [markdown]
# ## Now it's Matt and Josh's Turn

# %%
x2 = api.GetUserTimeline(screen_name="JNkappers", count=20, include_rts=False)
x2 = [_.AsDict() for _ in x2]

# %%
x2[0]
# Out:
# {u'created_at': u'Thu Jan 18 15:10:07 +0000 2018',
#  u'favorite_count': 1,
#  u'full_text': u'The royals, just like us \nhttps://t.co/dttTM8pcBs',
#  u'hashtags': [],
#  u'id': 954008004927610880,
#  u'id_str': u'954008004927610880',
#  u'lang': u'en',
#  u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  u'urls': [{u'expanded_url': u'https://thetab.com/uk/2018/01/18/prince-william-is-the-latest-posh-boy-to-shave-his-head-58471',
#    u'url': u'https://t.co/dttTM8pcBs'}],
#  u'user': {u'created_at': u'Mon Mar 09 21:19:31 +0000 2009',
#   u'description': u'Audience Development Editor @tabmediainc Occasional radio personality. Heir to the @kaplan_univ throne. Willing servant of the Zionist media conspiracy',
#   u'favourites_count': 5459,
#   u'followers_count': 1207,
#   u'following': True,
#   u'friends_count': 1075,
#   u'geo_enabled': True,
#   u'id': 23503335,
#   u'lang': u'en',
#   u'listed_count': 6,
#   u'location': u'United States',
#   u'name': u'Josh Kaplan',
#   u'profile_background_color': u'709397',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/793696735/1a5da7e0638158418c0e05dca8318bdb.jpeg',
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/23503335/1479851196',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/882681515691450369/zDUacpF3_normal.jpg',
#   u'profile_link_color': u'FF3300',
#   u'profile_sidebar_fill_color': u'A0C5C7',
#   u'profile_text_color': u'333333',
#   u'screen_name': u'JNkappers',
#   u'statuses_count': 4413,
#   u'time_zone': u'London',
#   u'url': u'https://t.co/IRgBnrAFGO'},
#  u'user_mentions': []}

# %%
y2 = api.GetUserTimeline(screen_name="mattjpfmcdonald", count=20, max_id=935706980643147777, include_rts=False)
y2 = [_.AsDict() for _ in y2]

# %%
y2[0]
# Out:
# {u'created_at': u'Wed Nov 29 02:46:29 +0000 2017',
#  u'favorite_count': 6,
#  u'full_text': u'go follow your local @TheTab school on instagram',
#  u'hashtags': [],
#  u'id': 935701470560882689,
#  u'id_str': u'935701470560882689',
#  u'lang': u'en',
#  u'retweet_count': 3,
#  u'source': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  u'urls': [],
#  u'user': {u'created_at': u'Thu Feb 05 20:52:02 +0000 2009',
#   u'description': u'us editor @thetab. previously subeditor @thesundaytimes/@st_sport. tips@thetab.com if you have a story, matt@thetab.com for all abuse. https://t.co/26kkQpFPUi',
#   u'favourites_count': 4570,
#   u'followers_count': 1104,
#   u'following': True,
#   u'friends_count': 982,
#   u'geo_enabled': True,
#   u'id': 20186557,
#   u'lang': u'en',
#   u'listed_count': 17,
#   u'location': u'New York',
#   u'name': u'Matt McDonald',
#   u'profile_background_color': u'000000',
#   u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/20186557/1497394847',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/875008940748267520/rRBq5lm6_normal.jpg',
#   u'profile_link_color': u'EE282E',
#   u'profile_sidebar_fill_color': u'000000',
#   u'profile_text_color': u'000000',
#   u'screen_name': u'mattjpfmcdonald',
#   u'statuses_count': 4401,
#   u'time_zone': u'Eastern Time (US & Canada)',
#   u'url': u'https://t.co/VrqButOTlq',
#   u'utc_offset': -18000},
#  u'user_mentions': [{u'id': 759319046,
#    u'name': u'The Tab',
#    u'screen_name': u'TheTab'}]}

# %%
for element in x2:
    print element['id']
    print(element['full_text'])
    print('--')
# Out:
# 954008004927610880
# The royals, just like us
# https://t.co/dttTM8pcBs
# --
# 953583065112117248
# If people don't start their tweets with "some personal news" how am I supposed to know who to mute????
# --
# 953223642741202945
# Day 3 of excessive Juul usage, 3 pods deeps and I can't remember what it feels like to not taste mangoes with every breath
# --

# %%
for element in y2:
    print element['id']
    print(element['full_text'])
    print('--')
# Out:
# 935701470560882689
# go follow your local @TheTab school on instagram
# --
# 935560026307129347
# no lol https://t.co/Xu3o3IAE44
# --
# 935186490929401857
# @ariellewastaken @idsnews why aren't they writing for @TheTab
# --
# 934973732896026625
# on my way back after a long, hard weekend of owning the libs
# --
# 934834620184645632
# and every time professor trelawney tells someone they are in ‘grave danger’, in the grand scheme of things she is probably right
# --
# 934831328574541828
# also that look ginny gives him when she’s leaving the room of requirement and he’s about to take the tongue express to chang town
# --
# 934829661506465794
# @edcmpbl what if umbridge found out the list existed and used the accio charm, they’d be fucked
# --
# 934828758003044352
# watching harry potter 5, the first thing their illegal magic group do is put their names on a list together, seems pretty counterintuitive
# --
# 934637009167110144
# @ABC @itsamandaross when did u have a kid
# --
# 934613481441112066
# you don’t choose your family, but there’s no-one else i’d pick https://t.co/fwnA8GQxPd
# --
# 934481662242643969
# like this if you’re aware that england are in a world cup final
# --
# 934159464298663936
# piers the website you write for said a lorry crashed into pedestrians. how can you hold olly murs to a higher standard than a news site? https://t.co/V8hHn1pYqL
# --
# 934119601910280195
# malia obama in ‘coolest kid at harvard’ shocker https://t.co/S6Z2xZlXBc
# --
# 934066496308989953
# ‘hi! i am emailing to ask if you are accepting guest posts at this t-‘ https://t.co/2QQldLaeU0
# --
# 933517695919775746
# @JNkappers R-fucking-T jo
# --
# 933343950370426880
# @JNkappers @carolinephinney @carrie_radigan was looking for an excuse to never speak to you again, thank you for providing one
# --

# %%
Josh = miner.mine_user_tweets(user="JNkappers")
Matt = miner.mine_user_tweets(user="mattjpfmcdonald")

# %%
for x2 in range(5):
    print Josh[x2]['text']
    print('---')
# Out:
# The royals, just like us
# https://t.co/dttTM8pcBs
# ---
# If people don't start their tweets with "some personal news" how am I supposed to know who to mute????
# ---
# Day 3 of excessive Juul usage, 3 pods deeps and I can't remember what it feels like to not taste mangoes with every breath
# ---
# Siri, show treatment options for Juul addiction
# ---
# Looooool https://t.co/v2qEKd5uDR
# ---

# %%
for x in range(5):
    print Matt[x]['text']
    print('--')
# Out:
# #ff my sister @sarahfmcdonald for all your godly needs, because it's her birthday and she OLD
# --
# @mikemancini my god
# --
# @TheTab also just seven-balled @mattgibson27 and @robertwhite2123 in pool https://t.co/pWim1s1b7u
# --
# @Ned_Donovan @TheTab the tab dot com is kinda like babedotnet but for uni
# --
# hate to brag but @TheTab’s american college accounts just cruised past 30,000 followers. so yeah, that’s how my week’s goin’
# --

# %%
josh_tweets = pd.DataFrame(Josh)
josh_tweets
# Out:
#                           created_at     handle                   mined_at  \
# 0     Thu Jan 18 15:10:07 +0000 2018  JNkappers 2018-01-20 02:45:22.315685
# 1     Wed Jan 17 11:01:34 +0000 2018  JNkappers 2018-01-20 02:45:22.315702
# 2     Tue Jan 16 11:13:21 +0000 2018  JNkappers 2018-01-20 02:45:22.315708
# 3     Mon Jan 15 20:05:05 +0000 2018  JNkappers 2018-01-20 02:45:22.315714
# 11                1  How has someone interviewed Floyd Mayweather, ...
# 12                0  Get it together lads, the family name is at st...
# 13                0  How has it got to the stage where I see 30 on ...
# 14                0  Just when you think @Quora isnt just white peo...
# 15                0                                               Fin.
# 16                0           “My mom’s calling ... how embarrassing,”
# 17                0  “Bro, my dad now arranged for you a $20bn deal...
# 18                0  "My dad made an awesome deal for your dad, bro...
# 19                0                          “Bro, you got to spot me"
# 20                0  The best quotes from Yair Netanyahu's outrageo...
# 21                0                                  @DixPeyton *fewer
# 22                0  Congrats on ur win James Franco, here are some...
# 23                0  I just wish Facebook had an option to hide any...
# 24                2  You vs. the guy she tells you not to worry abo...
# 25                0  I just.. I don't even know any more https://t....
# 26                0  And that man's name? Albert Einstein. https://...
# 27                0  I achieved something today! https://t.co/Rrs1v...
# 28                0  @GregBarradale you did it mate, you found the ...
# 29                0    @thebobpalmer Why were you at uni for 17 years?
# ...             ...                                                ...
# 1666              0   andrew marr, cutting as usual #coldstoreinslough
# 1667              0     Where's dimbledawg? I want my license fee back
# 1668              1  Who are the people that watch election coverag...
# 1669              0  Misty sunrise over the Berkshires from the rec...
# 1670              0  @ross_sian was in front of a packed restaurant...
# 1671              0  Walked face first into a glass door, broke my ...
# 1672              0  "Our day at hatch"- an abstract art piece from...
# 1673              0  @UoNSU I'm in the mood for something flame gri...
# 1674              0  Genuinely forgot that Plain Lazy clothes exist...
# 1675              0  Back home with ma bitch #demsurreyhillsdoe htt...
# 1676              0  BBC complaints reveal the big issues from whil...
# 1677              0  The view looking West from Citifield @ Citifie...
# 1678              0  Red Sox Blue Jays at Fenway @ Fenway Park http...
# 1679              0  Boston from the Charles river #ducktour @ Char...
# 1680              0                                @Zac_GB ur moist m8
# 1681              0  Watching #BRAvsMEX in an irish pub off times s...
# 1682              0  The fall of Eric Cantor is awful news for poli...
# 1683              0  Who are the people that need to buy duty free ...
# 1684              0  @NraWayne is the single most deluded man in we...
# 1685              0     You stay classy Cardiff http://t.co/HLVnB645Kl
# 1686              0  Who said London cabs were expensive? http://t....
# 1687              0  9 hours later, mans back in guildford via flee...
# 1688              0  Only took 7 hours, how time flies when you're ...
# 1689              0  @eastcoastuk are you able to say what they can...
# 1690              0  @eastcoastuk 18.45 Leeds to KingsX, I understa...
# 1691              0  Missed my connections and dangerously close to...
# 1692              0  Was quite looking forward to getting a job bef...
# 1693              0  Dissappointed to see that @netflix have kept t...
# 1694              0  @JakeReesMogg always brightens election covera...
# 1695              1  Two pints and change from a tenner, definitely...
#
#                 tweet_id
# 0     954008004927610880
# 1     953583065112117248
# 2     953223642741202945
# 3     952995071225417729
# 4     952915795146928128
# 5     952495771642974208
# 6     952493682468511744
# 7     952487748123942912
# 8     952486290842357760
# 9     951203804757753856
# 10    951198490004213763
# 11    951177849582612480
# 12    951115290405982208
# 13    950720564502630403
# 14    950574620893212672
# 15    950496919238905857
# 16    950496887655759872
# 17    950496596885680128
# 18    950496552220577792
# 19    950496485413740545
# 20    950496354144530432
# 21    950495273524060162
# 22    950195028651053056
# 23    949765030043705346
# 24    949397204078333953
# 25    949396242832019456
# 26    949293688638902272
# 18    @_CupOfT @DanaSchwartzzz you would love each o...  953078253916434432
# 19    fuck you very much @google https://t.co/SGqD2B...  953010011818680320
# 20                  @JNkappers  https://t.co/eiigDFWUUr  952995381809426433
# 21    overheard in my head every day: https://t.co/X...  952915086770933760
# 22    how dare you promote this to me @tide https://...  952408562420060161
# 23    what doesn’t kill you makes you stronger https...  952272517598797824
# 24    @wainz_world when you’re out with colleagues a...  951970601303932928
# 25    seeing the word ‘shithole’ everywhere today ha...  951963600419160064
# 26    the @adidas calling all creators campaign make...  951946581569343488
# 27    @SunPolitics @MrHarryCole harry why do you car...  951945710278184960
# 28                                      @VICE @HShukman  951617958291402753
# 29        @estwebber @Tom_Jenkin91 you must be so proud  951506356875546624
# ...                                                 ...                 ...
# 2233  @Nero @HShukman graduating from Cambridge and ...  565895642594439168
# 2234  @harrythieves what, Leonard Street? By Green P...  565870255759966208
# 2235                   @harrythieves *Whitecross Market  565869100359221248
# 2236                                    regret a manger  565868329169350656
# 2237  I got rejected from Cambridge in 2008 and Oxfo...  565860754688327680
# 2238  @sarahfmcdonald I hear some Jewish lads had a ...  565856066190458880
# 2239     message me 4 guestlist: http://t.co/oHLkKEGw7R  565526770066415619
# 2240   @charleswhite3 the ring chooses the ring-bearer.  564070017378304000
# 2241  @charleswhite3 I asked for one for Christmas. ...  564069736036962305
# 2242                      @charleswhite3 that is so uni  564068954722025474
# 2243                           SHIT! DID YOU SEE THAT?!  564068731677343744
# 2244                         @charleswhite3 ooh, where?  564068268856836096
# 2245  The kebab I had from @Mangal2 last night: grea...  564066069401587712
# 2246          @Liam__Evans I know, we're all over them.  564056817651949568
# 2247  @Jonny_Singer please show this to the next pla...  563673661459402752
# 2248  This one goes out to the boy in Bata @Jonny_Si...  563673570539483136
# 2249               @ExeterUniRL https://t.co/4Dvru1pApf  562998005637607425
# 2250                    @ExeterUniRL what's the score?!  562992653789581312
# 2251  An invigorating evening read from @kj_corcoran...  562324220936744960
# 2252  This whole piece by @OliDugmore reads like an ...  562301415876755456
# 2253  Kid put in isolation for having good lid. Ridi...  561121814764879872
# 2254  @Liam__Evans @Tom_Jenkin91 @imcraigoc can't yo...  560858637435158528
# 2255  @sarahfmcdonald it doesn't happen unless it ha...  560587364838670339
# 2256  @sarahfmcdonald she prayed to it aloud as she ...  560584694551830528
# 2257  @sarahfmcdonald after an hour and a half of ch...  560584589379649536
# 2258  My sister @sarahfmcdonald just killed the shit...  560584342460989440
# 2259            @Tom_Jenkin91 @imcraigoc? @Liam__Evans?  560563821828648960
# 2260  Would anyone like to come with me and @Tom_Jen...  560562666310479874
# 2261            @LisaFoxWrites @TheTab editor@tab.co.uk  560510825015029763
# 2262  @Christina_SvR @TheTab had to shove it in with...  560510454754463744
#
# [2263 rows x 6 columns]

# %%
tweets2 = pd.concat([josh_tweets, matt_tweets], axis=0)
tweets2.shape
# Out:
# (3959, 6)

# %%
# We can use the TfidfVectorizer to find ngrams for us
vect = TfidfVectorizer(ngram_range=(2,4), stop_words='english')

# Pulls all of Josh's tweet text's into one giant string
summaries = "".join(josh_tweets['text'])
ngrams_summaries = vect.build_analyzer()(summaries)

Counter(ngrams_summaries).most_common(20)
# Out:
# [(u'https wkz7janfeg', 51),
#  (u'follow dm', 27),
#  (u'nick_clegg borisjohnson', 25),
#  (u'details https', 16),
#  (u'nick_clegg borisjohnson ed_miliband', 15),
#  (u'details https wkz7janfeg', 15),
#  (u'borisjohnson ed_miliband', 15),
#  (u'write piece', 14),
#  (u'journo looking shadow', 13),
#  (u'shift write', 13),
#  (u'journo looking shadow junior', 13),
#  (u'piece job like interested', 13),
#  (u'looking shadow', 13),
#  (u'write piece job like', 13),
#  (u'piece job like', 13),
#  (u'job like', 13),
#  (u'like interested', 13),
#  (u'journo looking', 13),
#  (u'job like interested', 13),
#  (u'shift write piece job', 13)]

# %%
# We can use the TfidfVectorizer to find ngrams for us
vect = TfidfVectorizer(ngram_range=(2,4), stop_words='english')

# Pulls all of Matt's tweet text's into one giant string
summaries = "".join(matt_tweets['text'])
ngrams_summaries = vect.build_analyzer()(summaries)

Counter(ngrams_summaries).most_common(20)
# Out:
# [(u'thetab https', 40),
#  (u'hshukman thetab', 15),
#  (u'babedotnet carolinephinney', 13),
#  (u'rncincle https', 12),
#  (u'thetab story', 10),
#  (u'thetab exclusive', 10),
#  (u'thetab com', 9),
#  (u'piersmorgan spursofficial', 8),
#  (u'ericandalli piersmorgan', 8),
#  (u'fake news', 8),
#  (u'thetab scoop', 8),
#  (u'rewrite thetab', 8),
#  (u'marvel dccomics', 8),
#  (u'april fools', 8),
#  (u'ericandalli piersmorgan spursofficial', 8),
#  (u'like https', 7),
#  (u'ago https', 7),
#  (u'link https', 7),
#  (u'carolinephinney itsamandaross', 7),
#  (u'thetab babeswhodgaf', 7)]

# %%
tweet_text2 = tweets2['text'].values
clean_text2 = [preprocess_text(x, fix_unicode=True, lowercase=True, no_urls=True, no_emails=True, no_phone_numbers=True, no_currency_symbols=True,
                              no_punct=True, no_accents=True)
              for x in tweet_text2]

# %%
print clean_text2[1:8]
# Out:
# [u'if people dont start their tweets with some personal news how am i supposed to know who to mute', u'day 3 of excessive juul usage 3 pods deeps and i cant remember what it feels like to not taste mangoes with every breath', u'siri show treatment options for juul addiction', u'looooool url', u'ko14vonn tabmediainc yeah ofc dm me whenever', u'ko14vonn tabmediainc ive worked for tab media for a few years and happy to answer any more you have', u'ko14vonn feel free to check out tabmediainc for more details on who owns and publishes url feels pretty transparent to me']

# %%
y2 = tweets2['handle'].map(lambda x: 1 if x == 'mattjpfmcdonald' else 0).values
print max(pd.Series(y2).value_counts(normalize=True))
# Out:
# 0.57160899217

# %%
tfv = TfidfVectorizer(ngram_range=(1,5), max_features=2000)
X2 = tfv.fit_transform(clean_text2).todense()
print X2.shape
# Out:
# (3959, 2000)

# %%
lr2 = LogisticRegression()
params2 = {'penalty': ['l1', 'l2'], 'C':np.logspace(-5,0,100)}
#Grid searching to find optimal parameters for Logistic Regression
gs_2 = GridSearchCV(lr2, param_grid=params2, cv=10, verbose=1)
gs_2.fit(X2, y2)
# Out:
# Fitting 10 folds for each of 200 candidates, totalling 2000 fits
# [Parallel(n_jobs=1)]: Done 2000 out of 2000 | elapsed:  1.7min finished
# GridSearchCV(cv=10, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'penalty': ['l1', 'l2'], 'C': array([  1.00000e-05,   1.12332e-05, ...,   8.90215e-01,   1.00000e+00])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=1)

# %%
print gs_2.best_params_
print gs_2.best_score_
# Out:
# {'penalty': 'l2', 'C': 1.0}
# 0.664056579944

# %%
accuracies = cross_val_score(LogisticRegression(), X2, y2, cv=10, verbose=1)

print accuracies.mean()
print y2.mean()
# Out:
# 0.664034627756
# 0.57160899217
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.6s finished

# %%
estimator = LogisticRegression(penalty='l2', C=1.0)
estimator.fit(X2,y2)

# Prep our source as TfIdf vectors
source_test = [
    "I just wish Facebook had an option to hide any content with Action Bronson, it would really make me happy",
    "so my opening lines on bumble are so bad that girls unmatch me in some kind of men in black-style erasure of history. has happened twice."
]

Xtest = tfv.transform(source_test)
pd.DataFrame(estimator.predict_proba(Xtest), columns=["Proba_Josh", "Proba_Matt"])
# Out:
#    Proba_Josh  Proba_Matt
# 0    0.606615    0.393385
# 1    0.312974    0.687026

# %%
estimator.predict_proba(X2)
# Out:
# array([[ 0.53613428,  0.46386572],
#        [ 0.34640514,  0.65359486],
#        [ 0.69202063,  0.30797937],
#        ...,
#        [ 0.52103154,  0.47896846],
#        [ 0.04148497,  0.95851503],
#        [ 0.08955179,  0.91044821]])

# %%
Probas2 = pd.DataFrame(estimator.predict_proba(X2), columns=["Proba_Josh", "Proba_Matt"])
joined2 = pd.merge(tweets2, Probas2, left_index=True, right_index=True)

# %%
joined2.head()
# Out:
#                        created_at           handle                   mined_at  \
# 0  Thu Jan 18 15:10:07 +0000 2018        JNkappers 2018-01-20 02:45:22.315685
# 0  Fri Jan 19 16:44:44 +0000 2018  mattjpfmcdonald 2018-01-20 02:45:30.421313
# 1  Wed Jan 17 11:01:34 +0000 2018        JNkappers 2018-01-20 02:45:22.315702
# 1  Fri Jan 19 16:34:40 +0000 2018  mattjpfmcdonald 2018-01-20 02:45:30.421339
# 2  Tue Jan 16 11:13:21 +0000 2018        JNkappers 2018-01-20 02:45:22.315708
#
#    retweet_count                                               text  \
# 0              0  The royals, just like us \nhttps://t.co/dttTM8...
# 0              0  #ff my sister @sarahfmcdonald for all your god...
# 1              0  If people don't start their tweets with "some ...
# 1              0                                @mikemancini my god
# 2              0  Day 3 of excessive Juul usage, 3 pods deeps an...
#
#              tweet_id  Proba_Josh  Proba_Matt
# 0  954008004927610880    0.536134    0.463866
# 0  954394205039792128    0.536134    0.463866
# 1  953583065112117248    0.346405    0.653595
# 1  954391670052843520    0.346405    0.653595
# 2  953223642741202945    0.692021    0.307979

# %%
joined_josh = joined2[joined2['handle']=="JNkappers"]
for el in joined_josh[joined_josh['Proba_Josh']==max(joined_josh['Proba_Josh'])]['text']:
    print el
# Out:
# Pls ur majesty @Queen_UK
#
# https://t.co/smJpOLJfew

# %%
for el in joined_josh[joined_josh['Proba_Josh']==min(joined_josh['Proba_Josh'])]['text']:
    print el
# Out:
# @JordanStrack @joshi

# %%
joined_matt = joined2[joined2['handle']=="mattjpfmcdonald"]
for el in joined_matt[joined_matt['Proba_Matt']==max(joined_matt['Proba_Matt'])]['text']:
    print el
# Out:
# #dookfans eat gluten-free produce when they're not coeliac

# %% [markdown]
# ## I totally would have guessed that a tweet trolling Duke fans had the highest probability of being from Matt.

# %%
for el in joined_matt[joined_matt['Proba_Matt']==min(joined_matt['Proba_Matt'])]['text']:
    print el
# Out:
# @Oobahs the ones who aren't so freaked out that they never want to write again tend to go on to do great things
